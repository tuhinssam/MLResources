# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.impute import SimpleImputer
import seaborn as sns

# %%
df = pd.read_csv("horse.csv")

# %%
df.sample(10)
# Out:
#     surgery    age  hospital_number  rectal_temp  pulse  respiratory_rate  \
# 143     yes  adult           534519         37.1   84.0              40.0
# 280      no  adult           530624         40.0   78.0               NaN
# 41       no  young          5288249         39.0  150.0              72.0
# 208      no  adult           534478         37.5   44.0              10.0
# 265      no  adult           529865         38.6   68.0              20.0
# 107      no  adult           529764         37.3   50.0              32.0
# 46      yes  adult           529888         37.9   60.0              15.0
# 197      no  adult           533885         38.3   60.0              20.0
# 178      no  adult           528151         38.5  100.0               NaN
# 187     yes  adult           533887         38.5   60.0               NaN
#
#     temp_of_extremities peripheral_pulse mucous_membrane  \
# 143                cool          reduced   dark_cyanotic
# ...

# %%
cols=df.columns

# %%
df.isna().sum()
# Out:
# surgery                    0
# age                        0
# hospital_number            0
# rectal_temp               60
# pulse                     24
# respiratory_rate          58
# temp_of_extremities       56
# peripheral_pulse          69
# mucous_membrane           47
# capillary_refill_time     32
# pain                      55
# peristalsis               44
# abdominal_distention      56
# nasogastric_tube         104
# nasogastric_reflux       106
# nasogastric_reflux_ph    246
# rectal_exam_feces        102
# abdomen                  118
# packed_cell_volume        29
# total_protein             33
# abdomo_appearance        165
# abdomo_protein           198
# outcome                    0
# surgical_lesion            0
# lesion_1                   0
# lesion_2                   0
# lesion_3                   0
# cp_data                    0
# dtype: int64

# %%
df.count()
# Out:
# surgery                  299
# age                      299
# hospital_number          299
# rectal_temp              239
# pulse                    275
# respiratory_rate         241
# temp_of_extremities      243
# peripheral_pulse         230
# mucous_membrane          252
# capillary_refill_time    267
# pain                     244
# peristalsis              255
# abdominal_distention     243
# nasogastric_tube         195
# nasogastric_reflux       193
# nasogastric_reflux_ph     53
# rectal_exam_feces        197
# abdomen                  181
# packed_cell_volume       270
# total_protein            266
# abdomo_appearance        134
# abdomo_protein           101
# outcome                  299
# surgical_lesion          299
# lesion_1                 299
# lesion_2                 299
# lesion_3                 299
# cp_data                  299
# dtype: int64

# %%
imp = SimpleImputer(missing_values=np.nan,strategy="most_frequent")

# %%
dfnew = imp.fit_transform(df)

# %%
dfnew
# Out:
# array([['no', 'adult', 530101, ..., 0, 0, 'no'],
#        ['yes', 'adult', 534817, ..., 0, 0, 'no'],
#        ['no', 'adult', 530334, ..., 0, 0, 'yes'],
#        ...,
#        ['yes', 'adult', 529386, ..., 0, 0, 'no'],
#        ['yes', 'adult', 530612, ..., 0, 0, 'yes'],
#        ['yes', 'adult', 534618, ..., 0, 0, 'no']], dtype=object)

# %%
dfnew= pd.DataFrame(dfnew,columns=cols)

# %%
dfnew.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 28 columns):
# surgery                  299 non-null object
# age                      299 non-null object
# hospital_number          299 non-null object
# rectal_temp              299 non-null object
# pulse                    299 non-null object
# respiratory_rate         299 non-null object
# temp_of_extremities      299 non-null object
# peripheral_pulse         299 non-null object
# mucous_membrane          299 non-null object
# capillary_refill_time    299 non-null object
# pain                     299 non-null object
# peristalsis              299 non-null object
# abdominal_distention     299 non-null object
# nasogastric_tube         299 non-null object
# nasogastric_reflux       299 non-null object
# nasogastric_reflux_ph    299 non-null object
# rectal_exam_feces        299 non-null object
# abdomen                  299 non-null object
# ...

# %%
dfnew.sample(10)
# Out:
#     surgery    age hospital_number rectal_temp pulse respiratory_rate  \
# 296     yes  adult          529386        37.5    72               30
# 188     yes  adult         5299603        38.3    60               16
# 119      no  adult          535166        38.1    56               20
# 124      no  adult          529840        37.6    48               20
# 259      no  adult          534933          38    40               25
# 18      yes  adult         5290481        37.6    64               21
# 215      no  adult          528977          38    48               20
# 73      yes  adult          528469        38.1    52               24
# 147     yes  adult          529272        38.3   132               20
# 60       no  adult          530438        37.8    48               32
#
#     temp_of_extremities peripheral_pulse mucous_membrane  \
# 296                cold          reduced   pale_cyanotic
# 188                cool           normal     normal_pink
# ...

# %%
dfnew.drop(['hospital_number','lesion_1','lesion_2','lesion_3'], axis=1, inplace=True)

# %%
from sklearn.preprocessing import LabelEncoder
labelEncoder = LabelEncoder()

# %%
dfnew['surgery'] = labelEncoder.fit_transform(dfnew['surgery'].astype('str'))
dfnew['age'] = labelEncoder.fit_transform(dfnew['age'].astype('str'))
dfnew['temp_of_extremities'] = labelEncoder.fit_transform(dfnew['temp_of_extremities'].astype('str'))
dfnew['peripheral_pulse'] = labelEncoder.fit_transform(dfnew['peripheral_pulse'].astype('str'))
dfnew['mucous_membrane'] = labelEncoder.fit_transform(dfnew['mucous_membrane'].astype('str'))
dfnew['capillary_refill_time'] = labelEncoder.fit_transform(dfnew['capillary_refill_time'].astype('str'))
dfnew['abdomo_appearance'] = labelEncoder.fit_transform(dfnew['abdomo_appearance'].astype('str'))
dfnew['outcome'] = labelEncoder.fit_transform(dfnew['outcome'].astype('str'))
dfnew['cp_data'] = labelEncoder.fit_transform(dfnew['cp_data'].astype('str'))

# %%
dfnew.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 24 columns):
# surgery                  299 non-null int32
# age                      299 non-null int32
# rectal_temp              299 non-null object
# pulse                    299 non-null object
# respiratory_rate         299 non-null object
# temp_of_extremities      299 non-null int32
# peripheral_pulse         299 non-null int32
# mucous_membrane          299 non-null int32
# capillary_refill_time    299 non-null int32
# pain                     299 non-null object
# peristalsis              299 non-null object
# abdominal_distention     299 non-null object
# nasogastric_tube         299 non-null object
# nasogastric_reflux       299 non-null object
# nasogastric_reflux_ph    299 non-null object
# rectal_exam_feces        299 non-null object
# abdomen                  299 non-null object
# packed_cell_volume       299 non-null object
# total_protein            299 non-null object
# ...

# %%
dfnew.head()
# Out:
#    surgery  age rectal_temp pulse respiratory_rate  temp_of_extremities  \
# 0        0    0        38.5    66               28                    1
# 1        1    0        39.2    88               20                    1
# 2        0    0        38.3    40               24                    2
# 3        1    1        39.1   164               84                    0
# 4        0    0        37.3   104               35                    1
#
#    peripheral_pulse  mucous_membrane  capillary_refill_time          pain  \
# 0                 3                3                      2  extreme_pain
# 1                 2                4                      1     mild_pain
# 2                 2                5                      1     mild_pain
# 3                 2                2                      2     depressed
# 4                 2                2                      2     mild_pain
#
#     ...    nasogastric_reflux_ph rectal_exam_feces        abdomen  \
# ...

# %%
dfnew['pain'] = labelEncoder.fit_transform(dfnew['pain'].astype('str'))
dfnew['rectal_exam_feces'] = labelEncoder.fit_transform(dfnew['rectal_exam_feces'].astype('str'))
dfnew['abdomen'] = labelEncoder.fit_transform(dfnew['abdomen'].astype('str'))
dfnew['surgical_lesion'] = labelEncoder.fit_transform(dfnew['surgical_lesion'].astype('str'))

# %%
dfnew.head()
# Out:
#    surgery  age rectal_temp pulse respiratory_rate  temp_of_extremities  \
# 0        0    0        38.5    66               28                    1
# 1        1    0        39.2    88               20                    1
# 2        0    0        38.3    40               24                    2
# 3        1    1        39.1   164               84                    0
# 4        0    0        37.3   104               35                    1
#
#    peripheral_pulse  mucous_membrane  capillary_refill_time  pain   ...     \
# 0                 3                3                      2     2   ...
# 1                 2                4                      1     3   ...
# 2                 2                5                      1     3   ...
# 3                 2                2                      2     1   ...
# 4                 2                2                      2     3   ...
#
#   nasogastric_reflux_ph rectal_exam_feces abdomen packed_cell_volume  \
# ...

# %%
dfnew.corr()
# Out:
#                         surgery       age  temp_of_extremities  \
# surgery                1.000000  0.089319            -0.190183
# age                    0.089319  1.000000            -0.014282
# temp_of_extremities   -0.190183 -0.014282             1.000000
# peripheral_pulse       0.115915  0.027843            -0.193530
# mucous_membrane        0.041470 -0.170800            -0.089494
# capillary_refill_time  0.079588 -0.030065            -0.257690
# pain                   0.228871  0.058242            -0.188108
# rectal_exam_feces     -0.171611  0.003506             0.269007
# abdomen               -0.297202 -0.111078             0.169069
# abdomo_appearance      0.139274 -0.054823            -0.236222
# outcome               -0.189222 -0.101782             0.290367
# surgical_lesion        0.605023  0.044734            -0.226318
# cp_data                0.005827  0.079867            -0.052143
#
#                        peripheral_pulse  mucous_membrane  \
# ...

# %%
dfnew['pulse'] = dfnew['pulse'].astype(str).astype(float)
dfnew['rectal_temp'] = dfnew['rectal_temp'].astype(str).astype(float)
dfnew['respiratory_rate'] = dfnew['respiratory_rate'].astype(str).astype(float)
##dfnew['peristalsis'] = dfnew['peristalsis'].astype(str).astype(float)
#dfnew['abdominal_distention'] = dfnew['abdominal_distention'].astype(str).astype(float)
#dfnew['nasogastric_tube'] = dfnew['nasogastric_tube'].astype(str).astype(float)
#dfnew['nasogastric_reflux'] = dfnew['nasogastric_reflux'].astype(str).astype(float)
dfnew['nasogastric_reflux_ph'] = dfnew['nasogastric_reflux_ph'].astype(str).astype(float)
dfnew['packed_cell_volume'] = dfnew['packed_cell_volume'].astype(str).astype(float)
dfnew['total_protein'] = dfnew['total_protein'].astype(str).astype(float)

# %%
dfnew[['peristalsis','abdominal_distention','nasogastric_tube','nasogastric_reflux']].head(10)
# Out:
#   peristalsis abdominal_distention nasogastric_tube nasogastric_reflux
# 0      absent               severe           slight               none
# 1      absent               slight           slight               none
# 2  hypomotile                 none           slight               none
# 3      absent               severe             none       less_1_liter
# 4  hypomotile                 none           slight               none
# 5  hypomotile               slight           slight               none
# 6  hypomotile             moderate             none               none
# 7      absent               slight           slight               none
# 8      absent               severe           slight               none
# 9  hypomotile                 none           slight               none

# %%
dfnew['peristalsis'] = labelEncoder.fit_transform(dfnew['peristalsis'].astype(str))
dfnew['abdominal_distention'] = labelEncoder.fit_transform(dfnew['abdominal_distention'].astype(str))
dfnew['nasogastric_tube'] = labelEncoder.fit_transform(dfnew['nasogastric_tube'].astype(str))
dfnew['nasogastric_reflux'] = labelEncoder.fit_transform(dfnew['nasogastric_reflux'].astype(str))

# %%
dfnew.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 24 columns):
# surgery                  299 non-null int32
# age                      299 non-null int32
# rectal_temp              299 non-null float64
# pulse                    299 non-null float64
# respiratory_rate         299 non-null float64
# temp_of_extremities      299 non-null int32
# peripheral_pulse         299 non-null int32
# mucous_membrane          299 non-null int32
# capillary_refill_time    299 non-null int32
# pain                     299 non-null int32
# peristalsis              299 non-null int32
# abdominal_distention     299 non-null int32
# nasogastric_tube         299 non-null int32
# nasogastric_reflux       299 non-null int32
# nasogastric_reflux_ph    299 non-null float64
# rectal_exam_feces        299 non-null int32
# abdomen                  299 non-null int32
# packed_cell_volume       299 non-null float64
# total_protein            299 non-null float64
# ...

# %%
plt.figure(figsize=(16,10))
sns.heatmap(dfnew.corr(), annot=True)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
from sklearn.model_selection import train_test_split

# %%
#X = dfnew.drop('outcome',axis = 1)
X = dfnew.drop(['outcome','rectal_temp','respiratory_rate','mucous_membrane','nasogastric_tube','cp_data'],axis = 1)

# %%
y = dfnew.outcome

# %%
train_X,test_X,train_y,test_y = train_test_split(X,y, test_size=0.25)

# %%
dtc = DecisionTreeClassifier(random_state=89)

# %%
dtc.fit(train_X,train_y)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=89,
#             splitter='best')

# %%
dtcprediced = dtc.predict(test_X)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(test_y,dtcprediced)
# Out:
# 0.6266666666666667

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc =RandomForestClassifier(n_estimators=120)

# %%
rfc.fit(train_X,train_y)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=120, n_jobs=None,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
rfcPredict = rfc.predict(test_X)

# %%
accuracy_score(test_y,rfcPredict)
# Out:
# 0.72

# %%
dftestVsPredict = pd.DataFrame({"Test":test_y,"Predict":rfcPredict})

# %%
dftestVsPredict.sample(25)
# Out:
#      Test  Predict
# 276     2        2
# 62      0        0
# 98      2        2
# 245     2        0
# 30      0        0
# 197     2        2
# 14      2        2
# 298     1        2
# 24      2        2
# 36      1        2
# 237     1        0
# 193     2        2
# 1       1        2
# 3       0        0
# 257     2        2
# 10      2        2
# 26      2        2
# 121     1        0
# 21      2        2
# 289     2        2
# 125     2        2
# 163     2        2
# 234     0        0
# 50      2        2
# 18      2        2
