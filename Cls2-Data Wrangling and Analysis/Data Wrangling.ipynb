# %% [markdown]
# ## Data Wrangling using Python

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#import Boston Housing dataset

# %%
dfhousing = pd.read_csv("BostonHousing.csv")

# %%
dfhousing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
# crim       506 non-null float64
# zn         506 non-null float64
# indus      506 non-null float64
# chas       506 non-null int64
# nox        506 non-null float64
# rm         506 non-null float64
# age        506 non-null float64
# dis        506 non-null float64
# rad        506 non-null int64
# tax        506 non-null int64
# ptratio    506 non-null float64
# b          506 non-null float64
# lstat      506 non-null float64
# medv       506 non-null float64
# dtypes: float64(11), int64(3)
# memory usage: 55.4 KB

# %%
dfhousing.isna().sum()
# Out:
# crim       0
# zn         0
# indus      0
# chas       0
# nox        0
# rm         0
# age        0
# dis        0
# rad        0
# tax        0
# ptratio    0
# b          0
# lstat      0
# medv       0
# dtype: int64

# %%
dfhousing.count()
# Out:
# crim       506
# zn         506
# indus      506
# chas       506
# nox        506
# rm         506
# age        506
# dis        506
# rad        506
# tax        506
# ptratio    506
# b          506
# lstat      506
# medv       506
# dtype: int64

# %%
dfhousing.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         b  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
dfhousing.corr()
# Out:
#              crim        zn     indus      chas       nox        rm       age  \
# crim     1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219247  0.352734
# zn      -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311991 -0.569537
# indus    0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391676  0.644779
# chas    -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091251  0.086518
# nox      0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302188  0.731470
# rm      -0.219247  0.311991 -0.391676  0.091251 -0.302188  1.000000 -0.240265
# age      0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240265  1.000000
# dis     -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.205246 -0.747881
# rad      0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209847  0.456022
# tax      0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292048  0.506456
# ptratio  0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.355501  0.261515
# ...

# %%
plt.figure(figsize=(10,8))
sns.heatmap(dfhousing.corr(),annot=True)
plt.show()

# %%
dfhousing.describe()
# Out:
#              crim          zn       indus        chas         nox          rm  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677082   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               age         dis         rad         tax     ptratio           b  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
dfhousing.nunique()
# Out:
# crim       504
# zn          26
# indus       76
# chas         2
# nox         81
# rm         446
# age        356
# dis        412
# rad          9
# tax         66
# ptratio     46
# b          357
# lstat      455
# medv       229
# dtype: int64

# %%
len(dfhousing['age'].unique()) #number of Unique values in age column
# Out:
# 356

# %%
dfhousing.columns
# Out:
# Index(['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax',
#        'ptratio', 'b', 'lstat', 'medv'],
#       dtype='object')

# %%
dfhousing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
# crim       506 non-null float64
# zn         506 non-null float64
# indus      506 non-null float64
# chas       506 non-null int64
# nox        506 non-null float64
# rm         506 non-null float64
# age        506 non-null float64
# dis        506 non-null float64
# rad        506 non-null int64
# tax        506 non-null int64
# ptratio    506 non-null float64
# b          506 non-null float64
# lstat      506 non-null float64
# medv       506 non-null float64
# dtypes: float64(11), int64(3)
# memory usage: 55.4 KB

# %%
np.random.randn(8,5)
# Out:
# array([[-0.87485527, -1.2570977 ,  1.14015311,  0.82435667,  0.06771959],
#        [-0.39262732, -1.33943949,  1.38089086,  0.12782591,  2.43939928],
#        [ 0.80417948,  0.0430753 ,  0.20883432,  0.8497071 ,  0.49636187],
#        [ 1.26427031, -0.20855885,  0.1681819 , -0.51015312, -0.7203366 ],
#        [ 1.15110316,  0.490433  ,  0.18536506,  0.61932585, -0.68659105],
#        [-1.37749996,  0.94672715,  1.04203349, -0.29271044, -1.29777753],
#        [-0.00337708, -0.79400891,  0.7460966 ,  0.41954561, -0.51269073],
#        [ 0.02917618, -1.40507937,  1.13473563, -0.63321781, -0.14859387]])

# %%
df = pd.DataFrame(np.random.randn(8,5))

# %%
df
# Out:
#           0         1         2         3         4
# 0  0.605474 -1.708326 -0.173576  0.497389  0.045360
# 1 -0.519387  0.750774  0.712175 -0.354444 -1.406795
# 2 -0.630274 -0.866367 -0.243462 -0.529983 -2.027612
# 3  0.470649 -0.346163  1.610680 -0.804684 -0.014971
# 4 -0.893344  1.097007 -2.021275 -0.599505  0.990653
# 5 -0.653498 -0.579632 -0.708369  0.181460 -0.308906
# 6 -0.324013 -0.147846 -0.777520  0.596634  0.084966
# 7  0.479971  0.117381  0.403972  0.215777  0.449031

# %%
df = pd.DataFrame(np.random.randn(8,5),['p','q','r','s','t','u','v','w'],['a','b','c','d','e'])

# %%
df
# Out:
#           a         b         c         d         e
# p -1.036638  1.155739 -1.210445 -0.921985  0.588830
# q  1.366838 -1.284747  0.151213 -0.455691 -1.289672
# r -0.055937 -0.642860 -0.760370 -0.583271 -1.910055
# s  0.464936 -0.014409  0.085035  1.273858 -0.417073
# t  0.738433 -0.363894  0.563581  1.452614  0.680776
# u  0.765748  0.368376 -0.072599  0.370878  1.233741
# v -0.199861  1.806061  0.490064  1.504329  0.177935
# w  0.853188 -0.977571  2.883735 -0.268948 -0.186790

# %%
df['x']=df['d']+df['e']

# %%
df
# Out:
#           a         b         c         d         e         x
# p -1.036638  1.155739 -1.210445 -0.921985  0.588830 -0.333155
# q  1.366838 -1.284747  0.151213 -0.455691 -1.289672 -1.745362
# r -0.055937 -0.642860 -0.760370 -0.583271 -1.910055 -2.493326
# s  0.464936 -0.014409  0.085035  1.273858 -0.417073  0.856785
# t  0.738433 -0.363894  0.563581  1.452614  0.680776  2.133390
# u  0.765748  0.368376 -0.072599  0.370878  1.233741  1.604619
# v -0.199861  1.806061  0.490064  1.504329  0.177935  1.682265
# w  0.853188 -0.977571  2.883735 -0.268948 -0.186790 -0.455737

# %%
df.drop('x',axis=1,inplace=True)

# %%
df.drop('w',inplace=True)

# %%
df.loc[['p','q']]
# Out:
#           a         b         c         d         e
# p -1.036638  1.155739 -1.210445 -0.921985  0.588830
# q  1.366838 -1.284747  0.151213 -0.455691 -1.289672

# %%
df.loc['p','b']
# Out:
# 1.1557392428437474

# %%
df.loc[['p','q','s'],['d','e']]
# Out:
#           d         e
# p -0.921985  0.588830
# q -0.455691 -1.289672
# s  1.273858 -0.417073

# %%
df
# Out:
#           a         b         c         d         e
# p -1.036638  1.155739 -1.210445 -0.921985  0.588830
# q  1.366838 -1.284747  0.151213 -0.455691 -1.289672
# r -0.055937 -0.642860 -0.760370 -0.583271 -1.910055
# s  0.464936 -0.014409  0.085035  1.273858 -0.417073
# t  0.738433 -0.363894  0.563581  1.452614  0.680776
# u  0.765748  0.368376 -0.072599  0.370878  1.233741
# v -0.199861  1.806061  0.490064  1.504329  0.177935

# %%
df.iloc[0]
# Out:
# a   -1.036638
# b    1.155739
# c   -1.210445
# d   -0.921985
# e    0.588830
# Name: p, dtype: float64

# %%
df.iloc[[0,1]]
# Out:
#           a         b         c         d         e
# p -1.036638  1.155739 -1.210445 -0.921985  0.588830
# q  1.366838 -1.284747  0.151213 -0.455691 -1.289672

# %%
df.iloc[[0,1],[2,3]]
# Out:
#           c         d
# p -1.210445 -0.921985
# q  0.151213 -0.455691

# %%
df.iloc[2:,3:]
# Out:
#           d         e
# r -0.583271 -1.910055
# s  1.273858 -0.417073
# t  1.452614  0.680776
# u  0.370878  1.233741
# v  1.504329  0.177935

# %%
df<0
# Out:
#        a      b      c      d      e
# p   True  False   True   True  False
# q  False   True  False   True   True
# r   True   True   True   True   True
# s  False   True  False  False   True
# t  False   True  False  False  False
# u  False  False   True  False  False
# v   True  False  False  False  False

# %%
newdf= df[df>0]

# %%
newdf
# Out:
#           a         b         c         d         e
# p       NaN  1.155739       NaN       NaN  0.588830
# q  1.366838       NaN  0.151213       NaN       NaN
# r       NaN       NaN       NaN       NaN       NaN
# s  0.464936       NaN  0.085035  1.273858       NaN
# t  0.738433       NaN  0.563581  1.452614  0.680776
# u  0.765748  0.368376       NaN  0.370878  1.233741
# v       NaN  1.806061  0.490064  1.504329  0.177935

# %%
newdf.reset_index(inplace=True)
newdf
# Out:
#   index         a         b         c         d         e
# 0     p       NaN  1.155739       NaN       NaN  0.588830
# 1     q  1.366838       NaN  0.151213       NaN       NaN
# 2     r       NaN       NaN       NaN       NaN       NaN
# 3     s  0.464936       NaN  0.085035  1.273858       NaN
# 4     t  0.738433       NaN  0.563581  1.452614  0.680776
# 5     u  0.765748  0.368376       NaN  0.370878  1.233741
# 6     v       NaN  1.806061  0.490064  1.504329  0.177935

# %%
newdf.set_index("index",inplace=True)
newdf
# Out:
#               a         b         c         d         e
# index
# p           NaN  1.155739       NaN       NaN  0.588830
# q      1.366838       NaN  0.151213       NaN       NaN
# r           NaN       NaN       NaN       NaN       NaN
# s      0.464936       NaN  0.085035  1.273858       NaN
# t      0.738433       NaN  0.563581  1.452614  0.680776
# u      0.765748  0.368376       NaN  0.370878  1.233741
# v           NaN  1.806061  0.490064  1.504329  0.177935

# %%
newdf.loc[['p','s'],['a','c','d']]
# Out:
#               a         c         d
# index
# p           NaN       NaN       NaN
# s      0.464936  0.085035  1.273858

# %%
newdf.iloc[[1,2,3],[1,2,4]]
# Out:
#         b         c   e
# index
# q     NaN  0.151213 NaN
# r     NaN       NaN NaN
# s     NaN  0.085035 NaN

# %%
list(newdf.index)
# Out:
# ['p', 'q', 'r', 's', 't', 'u', 'v']

# %%
list(newdf.columns)
# Out:
# ['a', 'b', 'c', 'd', 'e']

# %%
newdf.fillna(0,inplace=True)

# %%
newdf=newdf[newdf!=0]

# %%
newdf['a'].isna().sum()
# Out:
# 3

# %%
newdf.isnull() # Checks values which are NaN (Not a Number)
# Out:
#        a      b      c      d      e
# p  False   True   True  False   True
# q   True   True   True  False   True
# r  False   True   True   True   True
# s   True  False   True  False   True
# t  False  False   True   True  False
# u  False  False  False   True   True
# v   True   True  False  False   True

# %%
newdf[newdf.notnull()] #Checks valus which are not null
# Out:
#           a         b         c         d        e
# p  0.429924       NaN       NaN  1.507210      NaN
# q       NaN       NaN       NaN  0.083962      NaN
# r  0.190001       NaN       NaN       NaN      NaN
# s       NaN  0.990340       NaN  0.215229      NaN
# t  0.557298  0.654166       NaN       NaN  0.22407
# u  1.130839  1.785134  0.641656       NaN      NaN
# v       NaN       NaN  0.583615  0.512537      NaN

# %%
newdf['a'].fillna(newdf['a'].mean(), inplace=True) #fill column a NaN values with mean

# %%
newdf
# Out:
#           a         b         c         d        e
# p  0.429924       NaN       NaN  1.507210      NaN
# q  0.577015       NaN       NaN  0.083962      NaN
# r  0.190001       NaN       NaN       NaN      NaN
# s  0.577015  0.990340       NaN  0.215229      NaN
# t  0.557298  0.654166       NaN       NaN  0.22407
# u  1.130839  1.785134  0.641656       NaN      NaN
# v  0.577015       NaN  0.583615  0.512537      NaN

# %%
newdf['e'].fillna(0, inplace=True)

# %%
newdf['d'].fillna(newdf['d'].median(), inplace=True)

# %%
newdf
# Out:
#           a         b         c         d        e
# p  0.429924       NaN       NaN  1.507210  0.00000
# q  0.577015       NaN       NaN  0.083962  0.00000
# r  0.190001       NaN       NaN  0.363883  0.00000
# s  0.577015  0.990340       NaN  0.215229  0.00000
# t  0.557298  0.654166       NaN  0.363883  0.22407
# u  1.130839  1.785134  0.641656  0.363883  0.00000
# v  0.577015       NaN  0.583615  0.512537  0.00000

# %%
for index,val in newdf.iteritems():
    print(index)
    print(val)
    print()
# Out:
# a
# p    0.429924
# q    0.577015
# r    0.190001
# s    0.577015
# t    0.557298
# u    1.130839
# v    0.577015
# Name: a, dtype: float64
#
# b
# p         NaN
# q         NaN
# r         NaN
# s    0.990340
# t    0.654166
# u    1.785134
# v         NaN
# Name: b, dtype: float64
#
# c
# p         NaN
# q         NaN
# r         NaN
# s         NaN
# t         NaN
# u    0.641656
# v    0.583615
# Name: c, dtype: float64
#
# d
# p    1.507210
# q    0.083962
# r    0.363883
# s    0.215229
# t    0.363883
# u    0.363883
# v    0.512537
# Name: d, dtype: float64
#
# e
# p    0.00000
# q    0.00000
# r    0.00000
# s    0.00000
# t    0.22407
# u    0.00000
# v    0.00000
# Name: e, dtype: float64

# %%
for index, row in df.iterrows():
    print(index)
    print(row)
    print()
# Out:
# p
# a    0.429924
# b   -0.551053
# c   -2.488771
# d    1.507210
# e   -0.259933
# Name: p, dtype: float64
#
# q
# a   -0.882960
# b   -0.255142
# c   -0.351570
# d    0.083962
# e   -0.139781
# Name: q, dtype: float64
#
# r
# a    0.190001
# b   -1.468747
# c   -0.765292
# d   -1.555401
# e   -0.021017
# Name: r, dtype: float64
#
# s
# a   -0.261718
# b    0.990340
# c   -0.332960
# d    0.215229
# e   -0.254298
# Name: s, dtype: float64
#
# t
# a    0.557298
# b    0.654166
# c   -1.412599
# d   -0.588455
# e    0.224070
# Name: t, dtype: float64
#
# u
# a    1.130839
# b    1.785134
# c    0.641656
# d   -0.363092
# e   -0.742010
# Name: u, dtype: float64
#
# v
# a   -0.937278
# b   -1.419122
# c    0.583615
# d    0.512537
# e   -0.637118
# Name: v, dtype: float64

# %%
for index in df.itertuples():
    print(index)
    print()
# Out:
# Pandas(Index='p', a=0.42992363608943585, b=-0.5510530961296043, c=-2.488770902391743, d=1.5072100695797654, e=-0.25993332552424975)
#
# Pandas(Index='q', a=-0.8829599251068584, b=-0.2551416247691008, c=-0.3515695703066455, d=0.0839623050762761, e=-0.13978071202379797)
#
# Pandas(Index='r', a=0.19000124989530337, b=-1.4687465810631641, c=-0.7652921968674105, d=-1.5554013917581797, e=-0.021016821252624385)
#
# Pandas(Index='s', a=-0.26171765356141447, b=0.9903404899523607, c=-0.3329599437326741, d=0.21522935826073544, e=-0.25429801858560697)
#
# Pandas(Index='t', a=0.5572975027966645, b=0.6541659531069074, c=-1.412599091686582, d=-0.588455005466504, e=0.22407039064098838)
#
# Pandas(Index='u', a=1.1308388047572664, b=1.7851336781894989, c=0.6416563364910247, d=-0.3630924003931535, e=-0.7420097694357386)
#
# Pandas(Index='v', a=-0.93727804818264, b=-1.4191219983250691, c=0.5836147071910364, d=0.5125372556910108, e=-0.6371182465099519)

# %%
dict1={'country':['India', 'Australia', 'WI', 'Pakistan', 'India', 'Australia', 'WI'], 'year':[2011, 2011,2011, 2011,2012, 2012, 2012], 'ranking':[1,2,3,4,1,2,4]}

# %%
dfcricket = pd.DataFrame(dict1)

# %%
dfcricket
# Out:
#      country  year  ranking
# 0      India  2011        1
# 1  Australia  2011        2
# 2         WI  2011        3
# 3   Pakistan  2011        4
# 4      India  2012        1
# 5  Australia  2012        2
# 6         WI  2012        4

# %%
print(dfcricket['country'].unique())
# Out:
# ['India' 'Australia' 'WI' 'Pakistan']

# %%
bycountry = dfcricket.groupby('country')

# %%
bycountry.get_group('India')[['year','ranking']]
# Out:
#    year  ranking
# 0  2011        1
# 4  2012        1

# %%
dfcricket[(dfcricket['country']=='India')&(dfcricket['year']==2011) ][['country','ranking']]
# Out:
#   country  ranking
# 0   India        1

# %%
dfcricket.sort_values(['country','ranking'],inplace=True)

# %%
dfcricket
# Out:
#      country  year  ranking
# 1  Australia  2011        2
# 5  Australia  2012        2
# 0      India  2011        1
# 4      India  2012        1
# 3   Pakistan  2011        4
# 2         WI  2011        3
# 6         WI  2012        4

# %%
dfcricket['country'].value_counts()
# Out:
# WI           2
# India        2
# Australia    2
# Pakistan     1
# Name: country, dtype: int64

# %%
for country,group in dfcricket.groupby('country'):
    print(country,len(group['year']))
# Out:
# Australia 2
# India 2
# Pakistan 1
# WI 2
